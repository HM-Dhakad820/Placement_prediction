# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/placement (1).csv')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.tail(10)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 90          90   7.3   86.0          1
# 91          91   7.5  158.0          1
# 92          92   5.2  110.0          0
# 93          93   6.8  112.0          1
# 94          94   4.7   52.0          0
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
# remove the column which is not in demand
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
plt.scatter(df['cgpa'], df['iq'], c = df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 97   6.7  182.0
# 26   7.0  199.0
# 4    5.8  142.0
# 75   4.8  169.0
# 89   4.9  151.0
# ..   ...    ...
# 62   6.0  102.0
# 56   6.1   65.0
# 50   3.5  233.0
# 48   6.6  138.0
# 92   5.2  110.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 23    0
# 25    0
# 55    1
# 81    0
# 11    1
#      ..
# 93    1
# 44    1
# 31    0
# 54    1
# 75    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 96   4.4   42.0
# 30   7.6  128.0
# 69   8.5  120.0
# 2    5.3  121.0
# 62   6.0  102.0
# 56   6.1   65.0
# 6    5.7  143.0
# 58   8.0   79.0
# 99   6.2  113.0
# 65   8.1  166.0

# %%
y_test
# Out:
# 96    0
# 30    1
# 69    1
# 2     0
# 62    0
# 56    0
# 6     0
# 58    1
# 99    1
# 65    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler  = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.11484111, -0.96201311],
#        [-0.84169492, -0.86160003],
#        [ 1.70766951, -0.28422481],
#        [-0.47750001, -0.4599477 ],
#        [ 0.88823094,  0.31825368],
#        [ 0.61508475,  0.31825368],
#        [ 0.70613348,  1.42279758],
#        [ 0.1598411 , -1.11263273],
#        [-0.56854874, -0.28422481],
#        [ 1.25242586, -0.23401827],
#        [ 0.97927967,  1.84955318],
#        [ 1.52557205, -0.91180657],
#        [-0.93274365,  0.2178406 ],
#        [-0.93274365,  0.6445962 ],
#        [-0.7506462 , -1.48918179],
#        [-0.02225636, -0.48505097],
#        [-0.93274365,  1.77424337],
#        [-0.84169492, -0.18381172],
#        [ 0.70613348,  0.71990601],
#        [ 1.0703284 , -1.94104066],
#        [ 0.34193856,  0.06722098],
#        [ 1.0703284 ,  0.6445962 ],
#        [-2.38952333,  1.44790085],
#        [ 0.43298729, -0.23401827],
#        [-1.20588984,  0.51907985],
#        [ 0.52403602, -0.8867033 ],
#        [-0.11330509,  1.02114526],
#        [-0.93274365, -1.61469814],
#        [ 0.79718221, -0.8867033 ],
#        [-1.02379238,  0.94583545],
#        [ 0.97927967,  1.24707469],
#        [-0.20435382,  0.16763406],
#        [-0.93274365,  0.74500928],
#        [ 0.1598411 ,  0.77011255],
#        [ 1.43452332,  0.11742752],
#        [-0.93274365, -0.13360518],
#        [ 0.79718221, -0.05829537],
#        [-0.65959747,  0.8956289 ],
#        [-0.65959747,  2.47713494],
#        [ 0.88823094, -0.73608367],
#        [-0.7506462 ,  1.27217796],
#        [ 0.34193856,  0.04211771],
#        [ 1.25242586,  0.29315041],
#        [ 1.9808157 ,  0.59438966],
#        [ 0.34193856, -0.56036078],
#        [-2.20742587,  2.70306438],
#        [-1.02379238, -0.33443135],
#        [ 1.43452332,  0.82031909],
#        [-1.02379238,  0.3935635 ],
#        [-0.65959747, -0.38463789],
#        [-0.47750001,  0.34335695],
#        [ 0.1598411 ,  0.16763406],
#        [ 0.88823094,  0.34335695],
#        [-0.84169492, -1.5644916 ],
#        [ 0.52403602,  0.11742752],
#        [ 0.52403602,  0.87052563],
#        [-0.20435382,  0.36846023],
#        [ 0.52403602, -2.21717663],
#        [-1.47903603,  1.87465645],
#        [ 0.06879237,  0.59438966],
#        [-0.7506462 ,  0.06722098],
#        [-0.47750001, -0.28422481],
#        [-1.75218222, -0.63567059],
#        [ 0.06879237, -1.48918179],
#        [-0.47750001,  0.24294387],
#        [-0.20435382,  1.09645507],
#        [-1.11484111, -0.10850191],
#        [-1.11484111, -1.84062757],
#        [ 0.06879237, -2.01635047],
#        [ 0.1598411 , -0.56036078],
#        [-0.65959747, -0.8867033 ],
#        [ 1.25242586, -1.89083412],
#        [ 0.97927967, -0.33443135],
#        [ 0.97927967, -1.53938833],
#        [-1.75218222, -1.26325235],
#        [ 0.06879237, -0.0331921 ],
#        [-0.11330509,  0.41866677],
#        [ 0.61508475, -0.13360518],
#        [ 0.79718221,  0.3935635 ],
#        [ 0.97927967,  0.34335695],
#        [ 1.25242586, -0.98711638],
#        [-0.65959747,  0.16763406],
#        [ 2.16291316,  1.0713518 ],
#        [ 1.34347459,  0.16763406],
#        [-1.3879873 ,  0.59438966],
#        [ 0.79718221, -0.33443135],
#        [ 1.43452332, -1.61469814],
#        [-1.84323095, -0.40974116],
#        [ 0.43298729,  0.3935635 ],
#        [-1.02379238,  1.09645507]])

# %%
x_train.shape
# Out:
# (90, 2)

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-1.3879873 , -2.09166028],
#        [ 1.52557205,  0.06722098],
#        [ 2.34501062, -0.13360518],
#        [-0.56854874, -0.10850191],
#        [ 0.06879237, -0.58546405],
#        [ 0.1598411 , -1.51428506],
#        [-0.20435382,  0.44377004],
#        [ 1.88976697, -1.16283927],
#        [ 0.25088983, -0.30932808],
#        [ 1.9808157 ,  1.02114526]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#now train the model
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 96    0
# 30    1
# 69    1
# 2     0
# 62    0
# 56    0
# 6     0
# 58    1
# 99    1
# 65    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
#colors=['lightblue','lightpink','lightgreen','lightyellow']
plot_decision_regions(x_train, y_train.values, clf = clf, legend=2)
#plt.xlabel('x_train')
#plt.ylabel('y_train')
#plt.title('Predition')
#plt.show()
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
